# %%
pip install plotly
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (5.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly) (8.4.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from plotly) (24.1)

# %%
import pandas as pd

# Membaca dataset dari file CSV
df = pd.read_csv('dataset_covid.csv')

# Menampilkan daftar negara yang ada di dalam dataset
countries = df['country'].unique()
print("Negara-negara yang terdaftar dalam dataset:")
for country in countries:
    print(country)
# Out:
# Negara-negara yang terdaftar dalam dataset:
# Australia
# China
# Denmark
# France
# Netherlands
# New Zealand
# United Kingdom

# %%
# !pip install geopandas matplotlib
# Out:
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.6)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (24.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.2.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2024.6.2)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2024.1)

# %%
import matplotlib.pyplot as plt
import geopandas as gpd

# %%
# !pip install folium
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.7.2)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2024.6.2)

# %%
# !pip install streamlit
# Out:
# Collecting streamlit
#   Downloading streamlit-1.36.0-py2.py3-none-any.whl (8.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 37.4 MB/s eta 0:00:00
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.1.7)
# Requirement already satisfied: numpy<3,>=1.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (1.25.2)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (9.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (14.0.2)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.10/dist-packages (from streamlit) (2.31.0)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (8.4.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit) (4.12.2)
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit)
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 13.6 MB/s eta 0:00:00
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 40.8 MB/s eta 0:00:00
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit) (6.3.3)
# Collecting watchdog<5,>=2.1.5 (from streamlit)
#   Downloading watchdog-4.0.1-py3-none-manylinux2014_x86_64.whl (83 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 10.6 MB/s eta 0:00:00
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.4)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (3.1.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit) (0.12.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.4 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.27->streamlit) (2024.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit) (2.16.1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->altair<6,>=4.0->streamlit) (2.1.5)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit) (1.16.0)
# Installing collected packages: watchdog, smmap, pydeck, gitdb, gitpython, streamlit
# Successfully installed gitdb-4.0.11 gitpython-3.1.43 pydeck-0.9.1 smmap-5.0.1 streamlit-1.36.0 watchdog-4.0.1

# %%
# !pip install streamlit-folium
# Out:
# Collecting streamlit-folium
#   Downloading streamlit_folium-0.21.0-py3-none-any.whl (326 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 327.0/327.0 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: streamlit>=1.13.0 in /usr/local/lib/python3.10/dist-packages (from streamlit-folium) (1.36.0)
# Requirement already satisfied: folium!=0.15.0,>=0.13 in /usr/local/lib/python3.10/dist-packages (from streamlit-folium) (0.14.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from streamlit-folium) (3.1.4)
# Requirement already satisfied: branca in /usr/local/lib/python3.10/dist-packages (from streamlit-folium) (0.7.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium!=0.15.0,>=0.13->streamlit-folium) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium!=0.15.0,>=0.13->streamlit-folium) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->streamlit-folium) (2.1.5)
# Requirement already satisfied: altair<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (4.2.2)
# Requirement already satisfied: blinker<2,>=1.0.0 in /usr/lib/python3/dist-packages (from streamlit>=1.13.0->streamlit-folium) (1.4)
# Requirement already satisfied: cachetools<6,>=4.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (5.3.3)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (8.1.7)
# Requirement already satisfied: packaging<25,>=20 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (24.1)
# Requirement already satisfied: pandas<3,>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (2.0.3)
# Requirement already satisfied: pillow<11,>=7.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (9.4.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (3.20.3)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (14.0.2)
# Requirement already satisfied: rich<14,>=10.14.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (13.7.1)
# Requirement already satisfied: tenacity<9,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (8.4.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (4.12.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (3.1.43)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (6.3.3)
# Requirement already satisfied: watchdog<5,>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from streamlit>=1.13.0->streamlit-folium) (4.0.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (0.4)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (4.19.2)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from altair<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (0.12.1)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.13.0->streamlit-folium) (4.0.11)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit>=1.13.0->streamlit-folium) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit>=1.13.0->streamlit-folium) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3,>=1.3.0->streamlit>=1.13.0->streamlit-folium) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->folium!=0.15.0,>=0.13->streamlit-folium) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium!=0.15.0,>=0.13->streamlit-folium) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium!=0.15.0,>=0.13->streamlit-folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium!=0.15.0,>=0.13->streamlit-folium) (2024.6.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit>=1.13.0->streamlit-folium) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich<14,>=10.14.0->streamlit>=1.13.0->streamlit-folium) (2.16.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.13.0->streamlit-folium) (5.0.1)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (23.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.13.0->streamlit-folium) (0.18.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich<14,>=10.14.0->streamlit>=1.13.0->streamlit-folium) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.3.0->streamlit>=1.13.0->streamlit-folium) (1.16.0)
# Installing collected packages: streamlit-folium
# Successfully installed streamlit-folium-0.21.0

# %% [markdown]
# # FRANCE

# %%
import folium
import json
from IPython.display import display

# Fungsi untuk menambahkan marker dengan label
def add_marker(map_obj, lat, lon, label):
    folium.Marker(
        location=[lat, lon],
        popup=label,
        icon=folium.Icon(color='red', icon='info-sign')
    ).add_to(map_obj)

# Lokasi dan nama daerah yang akan ditandai
locations = {
    'French Guiana': {'lat': 3.9339, 'lon': -53.1258},
    'French Polynesia': {'lat': -17.6797, 'lon': -149.4068},
    'Guadeloupe': {'lat': 16.265, 'lon': -61.551},
    'Martinique': {'lat': 14.6415, 'lon': -61.0242},
    'Mayotte': {'lat': -12.8275, 'lon': 45.1662},
    'New Caledonia': {'lat': -20.9043, 'lon': 165.618},
    'Reunion': {'lat': -21.1151, 'lon': 55.5364},
    'Saint Barthelemy': {'lat': 17.9, 'lon': -62.8333},
    'Saint Pierre and Miquelon': {'lat': 46.8852, 'lon': -56.3159},
    'St Martin': {'lat': 18.0708, 'lon': -63.0501},
    'Wallis and Futuna': {'lat': -13.7688, 'lon': -177.156},
}

# Membaca file GeoJSON France
with open('france.geojson', 'r') as f:
    geojson_data = json.load(f)

# Membuat objek peta
m = folium.Map(location=[20.0, -40.0], zoom_start=3)

# Menambahkan layer GeoJSON ke peta tanpa gaya yang berbeda untuk setiap region
for feature in geojson_data['features']:
    province_name = feature['properties']['name']
    folium.GeoJson(
        feature,
        name=province_name,
        tooltip=province_name
    ).add_to(m)

# Menambahkan marker atau label untuk setiap daerah yang akan ditandai
for location, coord in locations.items():
    add_marker(m, coord['lat'], coord['lon'], location)

# Menambahkan kontrol layer
folium.LayerControl().add_to(m)

# Menampilkan peta di notebook
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90f64318ed92cf756091389afa829c76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90f64318ed92cf756091389afa829c76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90f64318ed92cf756091389afa829c76 = L.map(
#                 &quot;map_90f64318ed92cf756091389afa829c76&quot;,
#                 {
#                     center: [20.0, -40.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8f03b61cae3ed7966ee64022fe1eddf3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_90f64318ed92cf756091389afa829c76);
#
#
#
#         function geo_json_72c25cfdc00d3cd463a20e7210d18521_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_72c25cfdc00d3cd463a20e7210d18521 = L.geoJson(null, {
#                 onEachFeature: geo_json_72c25cfdc00d3cd463a20e7210d18521_onEachFeature,
#
#         });
#
#         function geo_json_72c25cfdc00d3cd463a20e7210d18521_add (data) {
#             geo_json_72c25cfdc00d3cd463a20e7210d18521
#                 .addData(data)
#                 .addTo(map_90f64318ed92cf756091389afa829c76);
#         }
#             geo_json_72c25cfdc00d3cd463a20e7210d18521_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-52.33, 2.52], [-51.66, 4.27], [-53.33, 5.35], [-54.48, 4.23], [-54.27, 2.58], [-52.33, 2.52]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;French Guiana&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#
#
#
#             geo_json_72c25cfdc00d3cd463a20e7210d18521.bindTooltip(
#                 `&lt;div&gt;
#                      French Guiana
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#
#         function geo_json_ca78ecd35a4008c2c9bbcb6b15a8003e_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ca78ecd35a4008c2c9bbcb6b15a8003e = L.geoJson(null, {
#                 onEachFeature: geo_json_ca78ecd35a4008c2c9bbcb6b15a8003e_onEachFeature,
#
#         });
#
#         function geo_json_ca78ecd35a4008c2c9bbcb6b15a8003e_add (data) {
#             geo_json_ca78ecd35a4008c2c9bbcb6b15a8003e
#                 .addData(data)
#                 .addTo(map_90f64318ed92cf756091389afa829c76);
#         }
#             geo_json_ca78ecd35a4008c2c9bbcb6b15a8003e_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-149.57, -17.64], [-149.41, -17.49], [-149.29, -17.69], [-149.56, -17.88], [-149.73, -17.75], [-149.57, -17.64]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;French Polynesia&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#
#
#
#             geo_json_ca78ecd35a4008c2c9bbcb6b15a8003e.bindTooltip(
#                 `&lt;div&gt;
#                      French Polynesia
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#
#         function geo_json_c21e14d40ab86166d3c845ff0f8ddbec_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c21e14d40ab86166d3c845ff0f8ddbec = L.geoJson(null, {
#                 onEachFeature: geo_json_c21e14d40ab86166d3c845ff0f8ddbec_onEachFeature,
#
#         });
#
#         function geo_json_c21e14d40ab86166d3c845ff0f8ddbec_add (data) {
#             geo_json_c21e14d40ab86166d3c845ff0f8ddbec
#                 .addData(data)
#                 .addTo(map_90f64318ed92cf756091389afa829c76);
#         }
#             geo_json_c21e14d40ab86166d3c845ff0f8ddbec_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-61.79, 16.33], [-61.54, 16.42], [-61.29, 16.29], [-61.19, 16.22], [-61.39, 16.03], [-61.79, 16.33]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Guadeloupe&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#
#
#
#             geo_json_c21e14d40ab86166d3c845ff0f8ddbec.bindTooltip(
#                 `&lt;div&gt;
#                      Guadeloupe
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#
#         function geo_json_7e82dea7fe2ca5d4de9c0a062a7cda5b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_7e82dea7fe2ca5d4de9c0a062a7cda5b = L.geoJson(null, {
#                 onEachFeature: geo_json_7e82dea7fe2ca5d4de9c0a062a7cda5b_onEachFeature,
#
#         });
#
#         function geo_json_7e82dea7fe2ca5d4de9c0a062a7cda5b_add (data) {
#             geo_json_7e82dea7fe2ca5d4de9c0a062a7cda5b
#                 .addData(data)
#                 .addTo(map_90f64318ed92cf756091389afa829c7

# %% [markdown]
# # DENMARK

# %%
netherlands_provinces = df[df['country'] == 'Denmark']['province']

# Menggunakan value_counts untuk menghitung jumlah kemunculan setiap provinsi
province_counts = netherlands_provinces.value_counts()

# Tampilkan hasil
print(province_counts)
# Out:
# province
# Faroe Islands    816
# Greenland        816
# Name: count, dtype: int64

# %%
import folium
from IPython.display import display

# Fungsi untuk menambahkan marker dengan label
def add_marker(map_obj, lat, lon, label):
    folium.Marker(
        location=[lat, lon],
        popup=label,
        icon=folium.Icon(color='red', icon='info-sign')
    ).add_to(map_obj)

# Membaca file GeoJSON Denmark
with open('denmark.geojson', 'r') as f:
    denmark_geojson = json.load(f)

# Lokasi dan nama daerah yang akan ditandai
locations = {
    'Faroe Islands': {'lat': 62.0, 'lon': -6.8},
    'Greenland': {'lat': 71.7, 'lon': -42.6},
}

# Membuat objek peta
m = folium.Map(location=[60.0, 0.0], zoom_start=3)  # Koordinat tengah untuk Denmark

# Menambahkan layer GeoJSON ke peta tanpa gaya yang berbeda untuk setiap region
for feature in denmark_geojson['features']:
    province_name = feature['properties']['name']
    folium.GeoJson(
        feature,
        name=province_name,
        tooltip=province_name
    ).add_to(m)

# Menambahkan marker atau label untuk setiap daerah yang akan ditandai
for location, coord in locations.items():
    add_marker(m, coord['lat'], coord['lon'], location)

# Menambahkan kontrol layer
folium.LayerControl().add_to(m)

# Menampilkan peta di notebook
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_57ad417f17b6ccf11c37fe322d8939bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_57ad417f17b6ccf11c37fe322d8939bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_57ad417f17b6ccf11c37fe322d8939bb = L.map(
#                 &quot;map_57ad417f17b6ccf11c37fe322d8939bb&quot;,
#                 {
#                     center: [60.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4ca7e11678a73827eb0c1d146c780bef = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_57ad417f17b6ccf11c37fe322d8939bb);
#
#
#
#         function geo_json_6eb82a0ddbdac307d21a11f9f6f86c90_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_6eb82a0ddbdac307d21a11f9f6f86c90 = L.geoJson(null, {
#                 onEachFeature: geo_json_6eb82a0ddbdac307d21a11f9f6f86c90_onEachFeature,
#
#         });
#
#         function geo_json_6eb82a0ddbdac307d21a11f9f6f86c90_add (data) {
#             geo_json_6eb82a0ddbdac307d21a11f9f6f86c90
#                 .addData(data)
#                 .addTo(map_57ad417f17b6ccf11c37fe322d8939bb);
#         }
#             geo_json_6eb82a0ddbdac307d21a11f9f6f86c90_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[8.089976, 56.550422], [12.690006, 54.800015], [10.900007, 55.469999], [10.369993, 56.089993], [8.089976, 56.550422]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Denmark&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#
#
#
#             geo_json_6eb82a0ddbdac307d21a11f9f6f86c90.bindTooltip(
#                 `&lt;div&gt;
#                      Denmark
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#
#         function geo_json_224ebb42313b840fde77073e0e8cca7d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_224ebb42313b840fde77073e0e8cca7d = L.geoJson(null, {
#                 onEachFeature: geo_json_224ebb42313b840fde77073e0e8cca7d_onEachFeature,
#
#         });
#
#         function geo_json_224ebb42313b840fde77073e0e8cca7d_add (data) {
#             geo_json_224ebb42313b840fde77073e0e8cca7d
#                 .addData(data)
#                 .addTo(map_57ad417f17b6ccf11c37fe322d8939bb);
#         }
#             geo_json_224ebb42313b840fde77073e0e8cca7d_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-6.778827, 62.075653], [-6.833929, 61.892635], [-6.667732, 61.830699], [-6.386646, 62.025533], [-6.778827, 62.075653]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Faroe Islands&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#
#
#
#             geo_json_224ebb42313b840fde77073e0e8cca7d.bindTooltip(
#                 `&lt;div&gt;
#                      Faroe Islands
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#
#         function geo_json_ca6e8f88da15086b09ab1b4b91f2749f_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_ca6e8f88da15086b09ab1b4b91f2749f = L.geoJson(null, {
#                 onEachFeature: geo_json_ca6e8f88da15086b09ab1b4b91f2749f_onEachFeature,
#
#         });
#
#         function geo_json_ca6e8f88da15086b09ab1b4b91f2749f_add (data) {
#             geo_json_ca6e8f88da15086b09ab1b4b91f2749f
#                 .addData(data)
#                 .addTo(map_57ad417f17b6ccf11c37fe322d8939bb);
#         }
#             geo_json_ca6e8f88da15086b09ab1b4b91f2749f_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-42.446596, 83.644853], [-42.485065, 83.593046], [-42.385802, 83.537668], [-42.280296, 83.538675], [-42.239348, 83.562945], [-42.446596, 83.644853]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Greenland&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#
#
#
#             geo_json_ca6e8f88da15086b09ab1b4b91f2749f.bindTooltip(
#                 `&lt;div&gt;
#                      Greenland
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_66d039c2d388460907e7f21d22ea1b72 = L.marker(
#                 [62.0, -6.8],
#                 {}
#             ).addTo(map_57ad417f17b6ccf11c37fe322d8939bb);
#
#
#             var icon_1baabbb807ef937968546073d5df767e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}

# %% [markdown]
# # NETHERLANDS

# %%
netherlands_provinces = df[df['country'] == 'Netherlands']['province']

# Menggunakan value_counts untuk menghitung jumlah kemunculan setiap provinsi
province_counts = netherlands_provinces.value_counts()

# Tampilkan hasil
print(province_counts)
# Out:
# province
# Aruba                               816
# Bonaire, Sint Eustatius and Saba    816
# Curacao                             816
# Sint Maarten                        816
# Name: count, dtype: int64

# %%
import folium
import json
from IPython.display import display

# Fungsi untuk menambahkan marker dengan label
def add_marker(map_obj, lat, lon, label):
    folium.Marker(
        location=[lat, lon],
        popup=label,
        icon=folium.Icon(color='red', icon='info-sign')
    ).add_to(map_obj)

# Membaca file GeoJSON Netherlands
with open('netherlands.geojson', 'r') as f:
    netherlands_geojson = json.load(f)

# Lokasi dan nama daerah yang akan ditandai
locations = {
    'Aruba': {'lat': 12.5, 'lon': -69.97},
    'Bonaire, Sint Eustatius and Saba': {'lat': 17.6, 'lon': -63.06},
    'Curacao': {'lat': 12.2, 'lon': -68.93},
    'Sint Maarten': {'lat': 18.0, 'lon': -63.05},
}

# Membuat objek peta
m = folium.Map(location=[12.5, -69.97], zoom_start=8)  # Koordinat tengah untuk Aruba

# Menambahkan layer GeoJSON ke peta tanpa gaya yang berbeda untuk setiap region
for feature in netherlands_geojson['features']:
    province_name = feature['properties']['name']
    folium.GeoJson(
        feature,
        name=province_name,
        tooltip=province_name
    ).add_to(m)

# Menambahkan marker atau label untuk setiap daerah yang akan ditandai
for location, coord in locations.items():
    add_marker(m, coord['lat'], coord['lon'], location)

# Menambahkan kontrol layer
folium.LayerControl().add_to(m)

# Menampilkan peta di notebook
display(m)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8b9d4831ed12ddc64397ebf69f7d2ffc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8b9d4831ed12ddc64397ebf69f7d2ffc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8b9d4831ed12ddc64397ebf69f7d2ffc = L.map(
#                 &quot;map_8b9d4831ed12ddc64397ebf69f7d2ffc&quot;,
#                 {
#                     center: [12.5, -69.97],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 8,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee5b620e528c5a5ba6de90bf0f1c6df6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_8b9d4831ed12ddc64397ebf69f7d2ffc);
#
#
#
#         function geo_json_76bac4788892235e0b0e3df96e6bc4e2_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_76bac4788892235e0b0e3df96e6bc4e2 = L.geoJson(null, {
#                 onEachFeature: geo_json_76bac4788892235e0b0e3df96e6bc4e2_onEachFeature,
#
#         });
#
#         function geo_json_76bac4788892235e0b0e3df96e6bc4e2_add (data) {
#             geo_json_76bac4788892235e0b0e3df96e6bc4e2
#                 .addData(data)
#                 .addTo(map_8b9d4831ed12ddc64397ebf69f7d2ffc);
#         }
#             geo_json_76bac4788892235e0b0e3df96e6bc4e2_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[3.3168, 50.8636], [3.4315, 50.9013], [3.495, 50.8255], [3.3034, 50.7991], [3.3168, 50.8636]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Netherlands&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#
#
#
#             geo_json_76bac4788892235e0b0e3df96e6bc4e2.bindTooltip(
#                 `&lt;div&gt;
#                      Netherlands
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#
#         function geo_json_666043a7b775b609c19da817d8e122c0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_666043a7b775b609c19da817d8e122c0 = L.geoJson(null, {
#                 onEachFeature: geo_json_666043a7b775b609c19da817d8e122c0_onEachFeature,
#
#         });
#
#         function geo_json_666043a7b775b609c19da817d8e122c0_add (data) {
#             geo_json_666043a7b775b609c19da817d8e122c0
#                 .addData(data)
#                 .addTo(map_8b9d4831ed12ddc64397ebf69f7d2ffc);
#         }
#             geo_json_666043a7b775b609c19da817d8e122c0_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-70.0657, 12.6188], [-69.9885, 12.6146], [-69.9385, 12.4888], [-70.0657, 12.6188]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Aruba&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#
#
#
#             geo_json_666043a7b775b609c19da817d8e122c0.bindTooltip(
#                 `&lt;div&gt;
#                      Aruba
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#
#         function geo_json_60fdfa5a5c38fc03c5958f5288390ea0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_60fdfa5a5c38fc03c5958f5288390ea0 = L.geoJson(null, {
#                 onEachFeature: geo_json_60fdfa5a5c38fc03c5958f5288390ea0_onEachFeature,
#
#         });
#
#         function geo_json_60fdfa5a5c38fc03c5958f5288390ea0_add (data) {
#             geo_json_60fdfa5a5c38fc03c5958f5288390ea0
#                 .addData(data)
#                 .addTo(map_8b9d4831ed12ddc64397ebf69f7d2ffc);
#         }
#             geo_json_60fdfa5a5c38fc03c5958f5288390ea0_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-63.0326, 17.6257], [-63.0866, 17.6763], [-62.9537, 17.7222], [-63.0326, 17.6257]]]], &quot;type&quot;: &quot;MultiPolygon&quot;}, &quot;properties&quot;: {&quot;name&quot;: &quot;Bonaire, Sint Eustatius and Saba&quot;}, &quot;type&quot;: &quot;Feature&quot;});
#
#
#
#             geo_json_60fdfa5a5c38fc03c5958f5288390ea0.bindTooltip(
#                 `&lt;div&gt;
#                      Bonaire, Sint Eustatius and Saba
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#
#         function geo_json_8f829f52adb4b2ee29cfe6efe6aeb368_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8f829f52adb4b2ee29cfe6efe6aeb368 = L.geoJson(null, {
#                 onEachFeature: geo_json_8f829f52adb4b2ee29cfe6efe6aeb368_onEachFeature,
#
#         });
#
#         function geo_json_8f829f52adb4b2ee29cfe6efe6aeb368_add (data) {
#             geo_json_8f829f52adb4b2ee29cfe6efe6aeb368
#                 .addData(data)
#                 .addTo(map_8b9d4831ed12ddc64397ebf69f7d2ffc);
#         }
#             geo_j
